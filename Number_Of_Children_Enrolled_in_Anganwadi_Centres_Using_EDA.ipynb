# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = '/content/number_of_children_enrolled_in_anganwadis_2023_11.csv'
df = pd.read_csv(file_path)

# %%
print("Basic Info about the dataset:")
print(df.info())
# Out:
# Basic Info about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35700 entries, 0 to 35699
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Reporting Year          35700 non-null  int64
#  1   Reporting Month         35700 non-null  int64
#  2   D_Name                  35700 non-null  object
#  3   Proj_Name               35700 non-null  object
#  4   Sec_NAme                35700 non-null  object
#  5   AWC_ID                  35700 non-null  int64
#  6   AWc_Name                35700 non-null  object
#  7   Tot_Children_0to6M      35700 non-null  int64
#  8   Tot_Children_SC_0to6M   35700 non-null  int64
#  9   Tot_Children_ST_0to6M   35700 non-null  int64
#  10  Tot_Children_BC_0to6M   35700 non-null  int64
#  11  Tot_Children_OC_0to6M   35700 non-null  int64
#  12  Tot_Children_7Mto3Y     35700 non-null  int64
#  13  Tot_Children_SC_7Mto3Y  35700 non-null  int64
#  14  Tot_Children_ST_7Mto3Y  35700 non-null  int64
#  15  Tot_Children_BC_7Mto3Y  35700 non-null  int64
#  16  Tot_Children_OC_7Mto3Y  35700 non-null  int64
#  17  Tot_Children_3Yto6Y     35700 non-null  int64
#  18  Tot_Children_SC_3Yto6Y  35700 non-null  int64
#  19  Tot_Children_ST_3Yto6Y  35700 non-null  int64
#  20  Tot_Children_BC_3Yto6Y  35700 non-null  int64
#  21  Tot_Children_OC_3Yto6Y  35700 non-null  int64
# dtypes: int64(18), object(4)
# memory usage: 6.0+ MB
# None

# %%
print("\nFirst few rows of the dataset:")
print(df.head())
# Out:
# First few rows of the dataset:
#    Reporting Year  Reporting Month        D_Name       Proj_Name  Sec_NAme  \
# 0            2023               11  NAGARKURNOOL  ACHAMPETA (R)   Achampet
# 1            2023               11  NAGARKURNOOL  ACHAMPETA (R)   Achampet
# 2            2023               11  NAGARKURNOOL  ACHAMPETA (R)   Achampet
# 3            2023               11  NAGARKURNOOL  ACHAMPETA (R)   Achampet
# 4            2023               11  NAGARKURNOOL  ACHAMPETA (R)   Achampet
#
#     AWC_ID      AWc_Name  Tot_Children_0to6M  Tot_Children_SC_0to6M  \
# 0  1401001    Achampet-I                   4                      0
# 1  1401002   Achampet-II                   2                      0
# 2  1401003  Achampet-III                   5                      0
# 3  1401004   Achampet-IV                   1                      0
# 4  1401005    Achampet-V                   8                      6
#
#    Tot_Children_ST_0to6M  ...  Tot_Children_7Mto3Y  Tot_Children_SC_7Mto3Y  \
# 0                      0  ...                   45                       3
# 1                      0  ...                   17                       0
# 2                      0  ...                   33                       0
# 3                      0  ...                   31                       4
# 4                      1  ...                   31                      26
#
#    Tot_Children_ST_7Mto3Y  Tot_Children_BC_7Mto3Y  Tot_Children_OC_7Mto3Y  \
# 0                       1                      40                       1
# 1                       0                       8                       9
# 2                       0                      32                       1
# 3                       3                      18                       6
# 4                       2                       2                       1
#
#    Tot_Children_3Yto6Y  Tot_Children_SC_3Yto6Y  Tot_Children_ST_3Yto6Y  \
# 0                   26                       2                       4
# 1                   28                       1                       0
# 2                   30                       0                       1
# 3                   25                       5                       3
# 4                   22                      17                       3
#
#    Tot_Children_BC_3Yto6Y  Tot_Children_OC_3Yto6Y
# 0                      20                       0
# 1                      10                      17
# 2                      26                       3
# 3                      15                       2
# 4                       2                       0
#
# [5 rows x 22 columns]

# %%
print("\nSummary statistics of numerical columns:")
print(df.describe())
# Out:
# Summary statistics of numerical columns:
#        Reporting Year  Reporting Month        AWC_ID  Tot_Children_0to6M  \
# count         35700.0          35700.0  3.570000e+04        35700.000000
# mean           2023.0             11.0  1.892072e+06            3.649692
# std               0.0              0.0  3.005914e+05            3.479412
# min            2023.0             11.0  1.401001e+06            0.000000
# 25%            2023.0             11.0  1.702034e+06            1.000000
# 50%            2023.0             11.0  1.913186e+06            3.000000
# 75%            2023.0             11.0  2.116075e+06            5.000000
# max            2023.0             11.0  2.318252e+06           31.000000
#
#        Tot_Children_SC_0to6M  Tot_Children_ST_0to6M  Tot_Children_BC_0to6M  \
# count           35700.000000           35700.000000           35700.000000
# mean                0.745378               0.527983               1.925378
# std                 1.462583               1.250015               2.583897
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               0.000000               0.000000
# 50%                 0.000000               0.000000               1.000000
# 75%                 1.000000               0.000000               3.000000
# max                18.000000              25.000000              27.000000
#
#        Tot_Children_OC_0to6M  Tot_Children_7Mto3Y  Tot_Children_SC_7Mto3Y  \
# count           35700.000000         35700.000000            35700.000000
# mean                0.450952            27.388151                5.329804
# std                 1.326680            20.736894                7.853919
# min                 0.000000             0.000000                0.000000
# 25%                 0.000000            14.000000                0.000000
# 50%                 0.000000            23.000000                2.000000
# 75%                 0.000000            35.000000                8.000000
# max                30.000000           268.000000               91.000000
#
#        Tot_Children_ST_7Mto3Y  Tot_Children_BC_7Mto3Y  Tot_Children_OC_7Mto3Y  \
# count            35700.000000            35700.000000            35700.000000
# mean                 3.687843               14.956583                3.413922
# std                  6.500842               15.767780                9.322019
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                2.000000                0.000000
# 50%                  1.000000               11.000000                1.000000
# 75%                  5.000000               22.000000                3.000000
# max                136.000000              203.000000              167.000000
#
#        Tot_Children_3Yto6Y  Tot_Children_SC_3Yto6Y  Tot_Children_ST_3Yto6Y  \
# count         35700.000000            35700.000000            35700.000000
# mean             23.393389                4.745182                3.365070
# std              17.518200                7.352343                6.263567
# min               0.000000                0.000000                0.000000
# 25%              12.000000                0.000000                0.000000
# 50%              19.000000                1.000000                0.000000
# 75%              30.000000                7.000000                4.000000
# max             215.000000               99.000000              108.000000
#
#        Tot_Children_BC_3Yto6Y  Tot_Children_OC_3Yto6Y
# count            35700.000000            35700.000000
# mean                12.785742                2.497395
# std                 13.920837                6.733291
# min                  0.000000                0.000000
# 25%                  1.000000                0.000000
# 50%                  9.000000                0.000000
# 75%                 19.000000                2.000000
# max                158.000000              110.000000

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
# Out:
# <ipython-input-8-c47e933cac69>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Distribution of the 'Tot_Children_0to6M' column
plt.figure(figsize=(10, 6))
sns.histplot(df['Tot_Children_0to6M'], kde=True, color='blue')
plt.title("Distribution of Tot_Children_0to6M")
plt.xlabel("Number of Children")
plt.ylabel("Frequency")
plt.show()

# %%
# Box plot for 'Tot_Children_0to6M' across different categories
plt.figure(figsize=(14, 8))
sns.boxplot(x='D_Name', y='Tot_Children_0to6M', data=df)
plt.title("Boxplot of Tot_Children_0to6M across Districts")
plt.xlabel("District Name")
plt.ylabel("Number of Children")
plt.xticks(rotation=45)
plt.show()
